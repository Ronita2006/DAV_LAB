# %%
import pandas as pd 
import numpy as np 
from scipy.stats import skew, kurtosis 
uci_diabetes = pd.read_csv("uci_diabetes.csv") 
pima_diabetes = pd.read_csv("pmi_diabetes.csv") 
print("UCI Diabetes Dataset Sample:") 
print(uci_diabetes.head()) 
print("\nPima Indians Diabetes Dataset Sample:") 
print(pima_diabetes.head()) 
numerical_columns = ["Glucose", "BloodPressure", "SkinThickness", "Insulin", 
"BMI","DiabetesPedigreeFunction", "Age"] 
# Univariate Analysis Function 
def univariate_analysis(df, columns): 
    stats = {} 
    for col in columns: 
        stats[col] = { 
            "Mean": np.mean(df[col]), 
            "Median": np.median(df[col]), 
            "Mode": df[col].mode()[0], 
            "Variance": np.var(df[col], ddof=1), 
            "Standard Deviation": np.std(df[col], ddof=1), 
            "Skewness": skew(df[col]), 
            "Kurtosis": kurtosis(df[col]) 
        } 
    return pd.DataFrame(stats).T 
# Perform Univariate Analysis 
uci_stats = univariate_analysis(uci_diabetes, numerical_columns) 
pima_stats = univariate_analysis(pima_diabetes, numerical_columns) 
# Display Results 
print("\nUCI Diabetes Dataset Statistics:") 
print(uci_stats) 
print("\nPima Indians Diabetes Dataset Statistics:") 
print(pima_stats)
# Out:
# UCI Diabetes Dataset Sample:
#    Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0      148             72             35        0  33.6
# 1       85             66             29        0  26.6
# 2      183             64              0        0  23.3
# 3       89             66             23       94  28.1
# 4      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
#
# Pima Indians Diabetes Dataset Sample:
#    Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0      120             70             30        0  35.0
# 1      150             80             32      150  34.5
# 2      100             60             20       85  28.0
# 3      130             78             28      120  32.4
# 4      140             82             35      200  36.2
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                       0.5   25        0
# 1                       0.6   29        1
# 2                       0.3   22        0
# 3                       0.8   35        1
# 4                       0.9   40        1
#
# UCI Diabetes Dataset Statistics:
#                                 Mean    Median     Mode      Variance  \
# Glucose                   128.033333  118.5000  107.000   1091.550575
# BloodPressure              67.666667   70.0000   70.000    150.919540
# SkinThickness              19.333333   23.0000    0.000    247.471264
# Insulin                    93.933333    0.0000    0.000  34031.719540
# BMI                        31.600000   30.3000   25.600     35.812414
# DiabetesPedigreeFunction    0.441533    0.3215    0.205      0.191789
# Age                        35.400000   31.5000   21.000    137.489655
#
#                           Standard Deviation  Skewness  Kurtosis
# Glucose                            33.038622  0.747837 -0.383754
# BloodPressure                      12.284931 -1.127402  2.047026
# SkinThickness                      15.731219 -0.041385 -1.303152
# Insulin                           184.476881  2.857926  8.196625
# BMI                                 5.984347  0.734759 -0.175531
# DiabetesPedigreeFunction            0.437937  2.956155  9.310182
# Age                                11.725598  0.702674 -0.745176
#
# Pima Indians Diabetes Dataset Statistics:
#                             Mean  Median  Mode      Variance  \
# Glucose                   125.55  121.50  95.0    482.260526
# BloodPressure              72.45   71.00  70.0     63.628947
# SkinThickness              29.05   29.50  30.0     46.786842
# Insulin                   135.55  120.00   0.0  10982.365789
# BMI                        32.34   31.80  24.5     25.746737
# DiabetesPedigreeFunction    0.61    0.55   0.4      0.108316
# Age                        31.95   30.00  22.0     77.523684
#
#                           Standard Deviation  Skewness  Kurtosis
# Glucose                            21.960431  0.446480 -0.855755
# BloodPressure                       7.976775  0.413124 -0.399248
# SkinThickness                       6.840091  0.387689 -0.075387
# Insulin                           104.796783  0.695837  0.318457
# BMI                                 5.074124  0.691029  0.294206
# DiabetesPedigreeFunction            0.329114  1.118264  0.992268
# Age                                 8.804754  1.186966  0.954123
